# %%
# open a graph file, picle format, from figures/alola.plt and visualize it using netwulf

import pickle
import netwulf as nw

# load the graph
with open('graphs/unova_G.pkl', 'rb') as f:
    G = pickle.load(f)

# visualize the graph
nw.visualize(G)
# Out:
# (None, None)

# %%
# read dataframe from pkl file

import pandas as pd

df = pd.read_pickle('pokemon_clean.pickle')

# %%
df
# Out:
#                 pokemon                               abilities  \
# 0             Bulbasaur                 [overgrow, chlorophyll]
# 1               Ivysaur                 [overgrow, chlorophyll]
# 2              Venusaur                 [overgrow, chlorophyll]
# 3            Charmander                    [blaze, solar-power]
# 4            Charmeleon                    [blaze, solar-power]
# ..                  ...                                     ...
# 900            Ursaluna            [guts, bulletproof, unnerve]
# 901    Basculegion-male   [rattled, adaptability, mold-breaker]
# 902            Sneasler                [pressure, poison-touch]
# 903            Overqwil  [poison-point, swift-swim, intimidate]
# 904  Enamorus-incarnate                  [cute-charm, contrary]
#
#                   types         egg_groups  \
# 0       [grass, poison]   [monster, plant]
# 1       [grass, poison]   [monster, plant]
# 2       [grass, poison]   [monster, plant]
# ...

# %%
df2 = pd.read_pickle('all_seasons_df.pkl')

# %%
df2
# Out:
#                                                pokemon  \
# 001  [Pikachu, Mankey, Spearow, Gyarados, Hypnosis,...
# 002  [Goldeen, Pikachu, Rattata, Jigglypuff, Caterp...
# 003  [Pikachu, Caterpie, Beedrill, Ekans, Pidgeotto...
# 004  [Pikachu, Bulbasaur, Charmander, Beedrill, Pin...
# 005  [Geodude, Pikachu, Pidgeotto, Meowth, Butterfr...
# ..                                                 ...
# 143  [Pikachu, Mantyke, Meowth, Gyarados, Latias, W...
# 144  [Pikachu, Furret, Rotom, Chansey, Meowth, Lati...
# 145  [Yamask, Yanmega, Pikachu, Slakoth, Staryu, Li...
# 146  [Pikachu, Spinarak, Spearow, Beartic, Meowth, ...
# 147  [Poliwag, Krookodile, Pikachu, Mankey, Spearow...
#
#                                                   plot  season
# 001  Pokémon - I Choose You! (Japanese: ポケモン！きみにきめた...       1
# 002  Ash rushes into Viridian City with his gravely...       1
# 003  Ash discovers and catches a Caterpie—his first...       1
# ...
